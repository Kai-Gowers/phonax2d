# %%
import glob
import pickle
import random
import re
import sys
from typing import List

import ase
import ase.io
import numpy as np
from tqdm import tqdm

import jax
import jax.nn
import jax.numpy as jnp

# %%
force_xyz = ase.io.read('phonon_ddb_train.xyz', index=":", format = 'extxyz')
len(force_xyz)
# Out:
# 13680

# %%
idx = 10000
force_xyz[idx].info
# Out:
# {'id': 'mp-13898_SC111_2',
#  'energy': -45.08533842,
#  'stress': array([[-0.00609998,  0.00254767, -0.00306557],
#         [ 0.00254767, -0.02809065, -0.0007696 ],
#         [-0.00306557, -0.0007696 ,  0.00216902]])}

# %%
force_xyz[idx].arrays
# Out:
# {'numbers': array([55, 55, 11, 49,  9,  9,  9,  9,  9,  9]),
#  'positions': array([[2.19236301, 2.25298889, 2.08884927],
#         [6.65732453, 6.50848937, 6.58063848],
#         [0.06716699, 0.01733666, 0.04983581],
#         [4.40932545, 4.5714784 , 4.53626852],
#         [4.44756493, 4.52910283, 6.59359307],
#         [6.56050976, 4.50235937, 4.36147572],
#         [2.35956782, 4.34149395, 4.41786436],
#         [4.31053011, 2.47522266, 4.35332884],
#         [4.48455028, 4.59894308, 2.34633473],
#         [4.38651162, 6.48502222, 4.58751933]]),
#  'forces': array([[ 9.031000e-03,  5.730700e-02,  3.687390e-01],
#         [ 2.490200e-02,  4.660480e-01,  1.727590e-01],
#         [-8.803200e-02,  1.317720e-01,  2.249000e-03],
#         [ 7.246970e-01, -3.225184e+00, -1.528028e+00],
#         [-1.722000e-03, -2.161710e-01,  4.555580e-01],
#         [-3.881390e-01, -8.501100e-02,  1.851970e-01],
#         [-5.453320e-01,  2.830110e-01,  6.025500e-02],
# ...
